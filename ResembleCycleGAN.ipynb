# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonhero/resemble_gan/blob/master/ResembleCycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Feb  4 02:31:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    16W /  70W |      0MiB / 15360MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/yoonhero/resemble_gan
# Out:
# Cloning into 'resemble_gan'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 175 (delta 26), reused 120 (delta 17), pack-reused 45
# Receiving objects: 100% (175/175), 114.44 MiB | 15.13 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd resemble_gan/ResembleCycleGAN

# !python train.py --is-colab --batch-size=4
# Out:
# /content/resemble_gan/ResembleCycleGAN
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# 100% 32/32 [01:56<00:00,  3.63s/it, d_loss=0.501, g_loss=5.38]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.465, g_loss=4.36]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.453, g_loss=4.23]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.438, g_loss=4.16]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.439, g_loss=4.02]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.428, g_loss=3.98]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.419, g_loss=3.76]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.416, g_loss=3.72]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.413, g_loss=3.64]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.38s/it, d_loss=0.384, g_loss=3.61]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.374, g_loss=3.75]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.374, g_loss=3.54]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.365, g_loss=3.45]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.347, g_loss=3.59]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.38s/it, d_loss=0.272, g_loss=3.67]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.242, g_loss=3.65]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.22, g_loss=3.62]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.204, g_loss=3.57]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.184, g_loss=3.68]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.185, g_loss=3.71]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.183, g_loss=3.53]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.189, g_loss=3.62]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.38s/it, d_loss=0.167, g_loss=3.66]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.169, g_loss=3.57]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.174, g_loss=3.69]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.418, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.365, g_loss=3.15]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.32, g_loss=3.26]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.312, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.292, g_loss=3.23]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.273, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.291, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.278, g_loss=3.3]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.268, g_loss=3.28]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.241, g_loss=3.34]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.26, g_loss=3.33]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.244, g_loss=3.25]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.241, g_loss=3.25]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.231, g_loss=3.23]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.238, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.215, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.193, g_loss=3.4]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.192, g_loss=3.46]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.199, g_loss=3.36]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.203, g_loss=3.34]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.184, g_loss=3.29]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.179, g_loss=3.43]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.167, g_loss=3.34]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.179, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.175, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.176, g_loss=3.3]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.189, g_loss=3.3]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.156, g_loss=3.49]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.134, g_loss=3.54]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.146, g_loss=3.36]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.149, g_loss=3.35]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.158, g_loss=3.26]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.153, g_loss=3.3]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.145, g_loss=3.38]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.148, g_loss=3.26]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.163, g_loss=3.33]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.157, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.163, g_loss=3.36]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.153, g_loss=3.24]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.131, g_loss=3.29]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.154, g_loss=3.28]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.161, g_loss=3.22]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.144, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.154, g_loss=3.21]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.124, g_loss=3.38]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.105, g_loss=3.51]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.104, g_loss=3.37]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.077, g_loss=3.45]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.102, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.108, g_loss=3.32]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.114, g_loss=3.36]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.14, g_loss=3.28]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.153, g_loss=3.19]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.147, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.0889, g_loss=3.52]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.0876, g_loss=3.42]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.0652, g_loss=3.4]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.067, g_loss=3.47]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.0853, g_loss=3.34]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:17<00:00,  2.41s/it, d_loss=0.11, g_loss=3.22]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.119, g_loss=3.27]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.126, g_loss=3.24]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.138, g_loss=3.21]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.40s/it, d_loss=0.134, g_loss=3.18]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 32/32 [01:16<00:00,  2.39s/it, d_loss=0.145, g_loss=3.2]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
#   0% 0/32 [00:02<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 217, in <module>
#     train_loop(disc_H, disc_Z, gen_Z, gen_H, loader, opt_disc,
#   File "train.py", line 174, in train_loop
#     opt_gen.step()
#   File "/usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py", line 140, in wrapper
#     out = func(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py", line 23, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/optim/adam.py", line 234, in step
#     adam(params_with_grad,
#   File "/usr/local/lib/python3.8/dist-packages/torch/optim/adam.py", line 300, in adam
#     func(params,
#   File "/usr/local/lib/python3.8/dist-packages/torch/optim/adam.py", line 410, in _single_tensor_adam
#     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# KeyboardInterrupt
# ^C
