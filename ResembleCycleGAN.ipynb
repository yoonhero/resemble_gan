# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonhero/resemble_gan/blob/master/ResembleCycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Feb  4 06:23:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    49W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/yoonhero/resemble_gan
# Out:
# Cloning into 'resemble_gan'...
# remote: Enumerating objects: 500, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 500 (delta 13), reused 31 (delta 13), pack-reused 467
# Receiving objects: 100% (500/500), 418.83 MiB | 60.19 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
# %cd resemble_gan/ResembleCycleGAN

# !python train.py --is-colab --batch-size=8
# Out:
# [Errno 2] No such file or directory: 'resemble_gan/ResembleCycleGAN'
# /content/resemble_gan/ResembleCycleGAN
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# 100% 16/16 [00:21<00:00,  1.35s/it, d_loss=0.509, g_loss=6.6]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 16/16 [00:07<00:00,  2.21it/s, d_loss=0.469, g_loss=4.47]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 16/16 [00:07<00:00,  2.23it/s, d_loss=0.45, g_loss=4.31]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# 100% 16/16 [00:07<00:00,  2.24it/s, d_loss=0.445, g_loss=4.19]
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# => Saving checkpoint
# ...
